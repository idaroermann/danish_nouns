# %%
"""Nogle af id'erne er de samme. Det skyldes at flere af de faste udtryk ikke har 
et synset id, hvorfor de er slået sammen med det synset,
som repræsenterer betydningen af det givne ord i det faste udtryk.
En håndfuld ord har fået et link til id'et for dets synonym, eller nærmeste synonym. Se også kommentarer.
De betydninger, som er kommenteret væk, er ikke valgt som annotering i testmaterialet. 
Nogle af betydningerne fra testmaterialet refererer til samme synset i DanNet: ordbogen er noget mere finkornet.
Semdax indeholder en stor del af faste ydtryk, hvorfor det ville være synd at skære dé sætninger væk fra testmaterialet.

Some of the values (ids) are the same: Several of the idiomatic expression does not have a synset representation in DanNet,
and are therefore merged with the synset of the given targetword in the expression (the literal sense is considered)
A handful of wordsenses are linked to synonyms of that word sense, or nearest synonym. See the comments in the lines.
The out-commented senses is not chosen as an annotation by the annotators in the test material (SemDax). 
Some of the senses (other than the beforementioned idiomatic expressions) in the test material refers to the same synset in DanNe:
the dictionary is a bit more fine-grained than DanNet, so the dictionary-annotated test material must have some merged links to DanNet.
The test material  contains many idiomatic expression, which is why these senses are not cut off from the matrial,
but merged instead.

"""

key={}

key['ansigt-1']='7590'
key['ansigt-1b']='15549'
key['ansigt-1a']='37360'#37360	{ansigtsudtryk_1;" udtryk_3}	udtryk i ansigtet der afspejler en bestemt føl..
key['ansigt-3']='2363'
key['ansigt-3a']='2363'
key['ansigt-2']='67546'#fra synset {fremtoning_1_1}	person, dyr el. genstand der fremtræder på en ...	Human+Object
key['ansigt-2a']='65307'#fra synset {væsen_2_1} en persons naturlige væremåde som den afspejle...	3rdOrderEntity+Mental
#key['ansigt_F_blive lang i ansigtet']='7590'
key['ansigt-F-en-våd-klud-i-ansigtet']='7590'
#key['ansigt_F_i sit ansigts sved']='7590'
key['ansigt-F-lige-op-i-ansigtet/lige-op-i-éns-åbne-ansigt']='7590'
#key['ansigt_F_lægge ansigtet i de rette folder']='7590'
key['ansigt-F-med-et-menneskeligt-ansigt']='7590'
#key['ansigt_F_på éns glatte/ærlige ansigt']='7590'
#key['ansigt_F_redde ansigt']='7590'
key['ansigt-F-skære-ansigt/ansigter/lave-ansigt/ansigter']='7590'
key['ansigt-F-slag-i-ansigtet']='7590'
#key['ansigt_F_slynge nogen noget i hovedet (ansigte...']='7590'
key['ansigt-F-stå-ansigt-til-ansigt']='7590'
key['ansigt-F-stå-malet-i-ansigtet-på-nogen']='37360'
key['ansigt-F-sætte-ansigt-på']='7590'
key['ansigt-F-tabe/miste-ansigt']='7590'


key['blik-1-4a']='25956'
key['blik-1-1']='66681'
key['blik-2-1']='41542'#tyndt udhamret el. udvalset metalplade, især a...
key['blik-1-2']='72028' #fra synset {kig_1}	det at kigge (hurtigt) på nogen el. noget (Bru...	BoundedEvent+Agentive
key['blik-1-3']='37360'#fra synset {ansigtsudtryk_1;" udtryk_3}	udtryk i ansigtet der afspejler en bestemt føl...	Property+Physical
key['blik-1-4']='45182'#fra synset{kigge_1}	rette blikket i en bestemt retning (Brug: ""Bø...	UnboundedEvent+Experience+Physical
#key['Blik_F_finde nåde for nogens blik']='45182'
key['blik-F-få-blikket']='37360'
key['blik-F-indre-blik']='66681'

 
key['hold-1a']='5579'
key['hold-1b']='5579'
key['hold-1']='5579'
key['hold-2']='8265'
key['hold-3']='17039'
key['hold-4']='40436'
key['hold_5']='7823'#	fra {samling_7}	sammenføjning af forskellige sammenhørende del...	Place+Object+Artifact+Partdet at noget er fast eller holdes på plads	Static+Relation (ikke i WordTies)				
key['hold-5a']='22237' #fra troværdighed_1}	det at være troværdig (Brug: ""Når en præsiden..	#sandhed, troværdighed eller overensstemmelse m...	3rdOrder+Mental+Social (ikke i WordTies)				
key['hold_6']='75192'	#greb; det at holde fast SPROGBRUG sjældent	Static+Relation (ikke i WordTies)				
key['hold-6a']='71987' #fra {overblik_1}	det at (kunne) overskue noget indviklet el. er...    	#OVERFØRT overblik eller kontrol over en situat...	3rdOrder+Mental (ikke i WordTies)				
#key['hold_7']='51421'	#smertefuld stivhed i fx ryg- eller nakkemuskle...	Property+Physical+Condition (ikke i WordTies)				
key['hold-8']='67127'	#det at holde (hus)dyr SPROGBRUG sjældent	Static+Relation+Possesion (ikke i WordTies)				
key['hold-F-på-hold']='70927'#fra {bero,2_2}	befinde sig et sted, fx til opbevaring (Brug: ...							
key['hold_F_være/spille med på holdet']='24050'						


key['hul-1a']='58347'#åbent sår eller brud i huden eller et andet st...	natural+object+bodypart				
key['hul-1']='58347'
key['hul-1b']='58347'
key['hul-1-1b-1e']='2270'#Manden havde hul i bukserne og store huller i skoene #	gennembrudt, udgravet eller på anden måde opst...	place+object				
key['hul-1c']='31873'#	hver af de små fordybninger der findes på en g...	place+object+artifact
key['hul-1d']='18490'#FRA {tomrum_1_2}	frit, uudnyttet område el. tidsrum (Brug: ""Ce...	3rdOrderEntity+Mental	OVERFØRT noget der er tomt (og umuligt at udfy...	ikke i DanNet (ikke i download i hvert fald)				
key['hul-1f']='58364'#	OVERFØRT lille, indelukket og mørkt rum SPROGB...	building+object+part
key['hul-2']='58378'#	tomt mellemrum i en række eller kreds	place+object+part				
key['hul-3']='18260'#	sygdomsangrebet område i en tand, opstået ved ...	natural+object+bodypart				
key['hul-4']='58363'#	naturlig åbning i et menneskes krop ; den kvin...	natural+object+bodypart                                        
key['hul-2a']='20793'	#OVERFØRT område der mangler at være dækket ind...	3rdOrder+mental				
key['hul-2b']='57221'	#OVERFØRT økonomisk udgift eller gæld som der m...	3rdOrder+quantity				
key['hul-2c']='74662'	#OVERFØRT tomrum i et forløb, fx en tidsperiode...	3rdOrder+time				
key['hul-F-få-hul-på-noget']='2270'						
#key['Hul_F_drikke som et hul i jorden']='2270'						
#key['Hul_F_(skid) hul i(=pyt med det)']='2270'						
key['hul-F-gå-hul']='2270'						
key['hul-F-hul-igennem']='2270'						
key['hul-F-hul-i-hovedet']='2270'						
key['hul-F-hul-i-jorden']='2270'						
key['hul-F-hul-på-bylden']='2270'						
key['hul-F-skide-hul-i']='2270'						
#key['Hul_F_slå (prikke, ..) hul på']='67473'						
key['hul-F-sort-hul']='37519'						
key['hul-F-tage-hul-på-noget']='67474'

  
key['kort-1']='20659'
key['kort-1c']='20659'#det er .. ikke pengeinstitutterne, der afgør, hvornår en kunde skal hæfte for en tyvs misbrug af kort og kode
key['kort-1b']='25176'#"Hvor mange gange skal jeg klippe på et gult kort til Hillerød." "To klip"
key['kort-1a']='25182'#Fra brevkort: Da jeg samler på danske postkort, vil jeg blive meget glad, hvis [nogen] vil sende mig nogle kort
key['kort-1e']='25201'#kort som dokumenterer at en person er den vedkommende giver sig ud for
key['kort-3']='25197'#Der spilles stadig kort .. Men nu spiller vi kun om øl. Ikke penge SeHør1983
key['kort-2a']='25238'#i fremtiden vil [der] blive lavet kort over alle menneskers arveanlæg
key['kort-2']='25238'#Bogen indeholdt et geodætisk kort over Danmark .. og kort over 200 danske byer
key['kort-4']='25269'#[han har] bygget en komplet 16-bit datamat med 91 integrerede kredsløb på et enkelt kort
key['kort-F-lægge-kortene-på-bordet']='32121'
key['kort-F-gult-kort']='25202'
key['kort-F-røde-kort']='25203'
key['kort-F-blande-kortene']='25197'
key['kort-F-gult-kort-overført']='25202'
key['kort-F-have-gode-kort-på-hånden']='25197'
key['kort-F-holde-kortene-tæt-ind-til-kroppen']='25197'
key['kort-F-kigge-nogen-i-kortene']='25197'
key['kort-F-ligge-i-kortene']='25197'
key['kort-F-røde-kort-overført']='25203'
#key['Kort_F_spille med skjulte/fordækte kort']='25197'
key['kort-F-spille-med-åbne-kort']='25197'
key['kort-F-spille-sine-kort-godt/dårligt']='25197'
key['Kort_F_sætte alt på et kort']='25197'


key['lys-1']='29405'
key['lys-1a']='37263' #fra stråling_1
key['lys-1b']='29391' #Fra dagslys_1
key['lys-1c']='58462' #Fra lampelys_0
key['lys-1h']='47346'
key['lys-2']='73014' #Fra rampelys_2: Scenografen arbejder naturligvis tæt sammen med teknikerne. At sætte lys til en teaterforestilling er et helt fagområde for sig
key['lys-1d']='18340'
key['lys-1e']='78536'
key['lys-1f']='78537'
key['lys-1g']='14410'
key['lys-3']='24870'
key['lys-4']='5788'
key['lys-5']='7306'
#key['lys_F_bengalsk lys']='24870'
#key['lys_F_brænde sit lys i begge ender']='24870'
key['lys-F-der-går-et-lys-op-for-nogen']='78536'
key['lys-F-føre-nogen-bag-lyset']='29405'
key['lys-F-grønt/gult/rødt-lys']='47363'
key['lys-F-grønt-lys(for-noget)']='47363'
key['lys-F-gå-ud-som-et-lys']='74719'
key['lys-F-i-et-nyt-(andet,-..)-lys']='29405'
key['lys-F-i-lyset-af']='29405'
key['lys-F-kaste-lys-over']='29405'
key['lys-F-komme-for-dagens-lys']='29405'
key['lys-F-lede/søge-med-lys-og-lygte']='5788'
key['lys_F_levende lys']='24870'
key['lys-F-lys-i-mørket']='14411'
#key['lys_F_rank som et lys']='24870'
key[ 'lys-F-komme/bringe-frem-i-lyset']='29405'
key['lys-F-se-lyset']='78536'
key['lys-F-stille/sætte-i-et-dårligt-lys']='29405'
key['lys-F-tåle-dagens-lys']='29405'
key['lys-F-sætte-sit-lys-under-en-skæppe']='24870'
key['lys-F-se-dagens-lys']='29405'

key['model-1']='42152'
key['model-1a']='7443'
key['model-2']='42153'
key['model-3']='15683'
key['model-4']='42150'
key['model-5']='7433'
key['model-6']='7438'
key['model-6a']='7449'
key['model-F-stå-model-til']='7433'


key['plade-1']='286'
key['plade-1a']='14135'
key['plade-F-panser-og-plade']='2707'
key['plade-1b']='14534'
key['plade-1c']='14535'
key['plade-2']='47878'
key['plade-2a']='23793'
#key['Plade_3']='41540'
key['plade-4']='58948'
key['plade-F-gule-plader']='58947'
#key['Plade_F_sorte plader']='58949'
key['plade-F-stikke-en-plade']='72750'
#key['Plade_7']='4030'
#key['Plade_F_fotografisk plade']='18530'
key['plade-6']='18526'
key['plade-5']='18591'
#key['Plade_F_barn på gule plader']='58947'
key['plade-F-hvide-plader']='41540'
#key['Plade_F_klippe pladerne']='41540'
#key['plade_F_sætte en anden/ny plade på grammofonen']='3793'

key['skade-1-1']='37313'
key['skade-2-1']='11363'
#key['Skade2_2']='35851'
key['skade-1-1c']='41271'# fra {skadevirkning_1}	skade opstået som følge af noget;" negativ føl... #Satte vi produktionen op .. ville der stå en Morgan på hvert andet gadehjørne til skade for efterspørgslen 
key['skade-1-1b']='67613'#hash kan give psykiske skader
key['skade-1-1a']='38653'
#key['skade_F_af skade bliver man klog']='38653'
key['skade-F-det-er-ingen-skade-til']='38653'
key['skade-F-(det-er/var)-skade']='75089'#fra {skam,1_3}	beklageligt, ærgerligt el. uheldigt forhold (B...	Property+Mental
key['skade-F-føje-spot-til-skade']='38653'
#key['skade_F_ikke komme nogen til skade']='38653'
key['skade-F-komme-for-skade']='38653'
key['skade-F-komme-til-skade']='38653'
key['skade-F-slå-halv-skade']='37313'
key['skade-F-tage/lide-skade']='38653'
#key['skade_F_tage skade for hjemgæld']='37313'

key['slag-4a']='37213'#fra bogstavelig betydning i slag-4
key['slag-4']='37213'
key['slag-6b']='24091'
key['slag-1']='22414'
key['slag-2b']='31301'
key['slag-1c']='48605'
key['slag-3']='17951' 
key['slag-6']='37293'#fra terningkast. #tur i spil hvor man kaster en eller flere terninger og evt. rykker sin brik på spillebrættet
key['slag-3a']='72503' #fra synonym pulsslag
key['slag-2c']='31301'
key['slag-2']='31301'
#key['Slag_5']='2662'
key['slag-6a']='24091'
key['slag-1a']='22414'
key['slag-1b']='56270'#{øretæve_1_1}	nederlag; modgang;" kritik (Brug: ""De konserv...
key['slag-2a']='37371'
key['slag-7']='9545'
#key['Slag_8']='35023'
key['slag-F-frit-slag']='56973'#{adgang_1_1}	mulighed for el. ret til at få fat i noget el....	3rdOrderEntity
key['slag-F-klokken-falder-i-slag']='67203' #fra klokkeslag
key['slag-F-med-ét-slag']='67203'
key['slag-F-hjerte-springer-slag-over']='17951'
key['slag-F-på-slaget']='67204'
key['slag-F-slag-i-ansigtet']='22414'
key['slag-F-slag-i-bolledejen']='22414'
key['slag-F-slag-i-luften']='22414'
key['slag-F-slag-i-slag']='9545'
key['slag-F-slag-på-tasken']='27489'# eksisterede i forvejen
#key['Slag_F_slag/stød under bæltestedet']='22414'
key['slag-F-slå-et-slag']='22414'
key['Slag_F_små slag)']='22414'
#key['Slag_F_springe et (par) slag over']='17951'
key['slag-F-stor-i-slaget']='22414'


key['stykke-5b']='15433'
key['stykke-5c']='14185'#afgrænset del af en tekst #fra tekststykke
key['stykke-1']='14177'
key['stykke-1a']='48798'
key['stykke-2']='14178'
key['stykke-2a']='35533'#del af et (dyrket) område. {jordstykke_1}
key['stykke-3']='36802'
key['stykke-3a']='20970'
key['stykke-4']='49018'
key['stykke-4a']='6918'
key['stykke-4b']='10004'
key['stykke-4c']='16018'#selvstændig, sammenhængende helhed betragtet s... #fra synset "to alen af et stykke
key['stykke-4d']='39044'
key['stykke-5']='28274'
key['stykke-5a']='15432'
key['stykke-5d']='38589'

#key['Stykke_6']='15777'
#key['Stykke_7']='59182'
#key['stykke_F_i stykker']='25639'
#key['stykke_F_stykke mad(=smørrebrød']='35974'
#key['stykke_F_være to alen (ud) af ét stykke']='16018'
#key['stykke_F_blæse noget/nogen et stykke']='10004'					
#key['stykke_F_det var/er et stift stykke']='10004'					
key['stykke-F-en-4-5-(25,-tusind,-..)-stykker']='49018'					
key['stykke-F-et-langt-stykke-(af-vejen)/et-langt-stykke-hen-ad-vejen']='36802'						
#key['stykke_F_et stort stykke af(=et typisk eksempe...']='10004'						
#key['stykke_F_i det stykke(sj.)']='49018'
key['stykke-F-i-stumper-og-stykker']='14177'						
key['stykke-F-når-det-kommer-til-stykket']='36802'						
#key['stykke_F_pille fra hinanden (i, stykker, ..)']='14177'						
#key['stykke_F_skide nogen/noget et stykke']='10004'
key['stykke-F-i-stykker']='14177'
key['stykke-F-slå-i-stykker']='14177'
key['top-2a']= '10016'
key['top-2b']='63072'#fra topledelse
key['top-1a']='15794'
key['top-1']='38394'
key['top-2']='10016'
key['top-3']='3010'
#key['Top_4']='59136'
#key['Top_F_der er koldt på toppen']='38394'						
key['top-F-fra-top-til-tå']='38394'						
key['top-F-på-toppen-af']='38394'						
key['top-F-til-tops']='38394'					
key['top-F-toppen-af-isbjerget']='38394'					
key['top-F-toppen-af/på-kransekagen']='38394'					
key['top-F-tånd/grå-i-toppen']='38394'


key['vold1-1a']='25330'
key['vold1-1b']='25334'
key['vold1-1c']='69808'#OVERFØRT overgreb der krænker en rettighed, ku... . synset fra overgreb_1, fysisk eller psykisk krænkelse af en svagere ...
key['vold1-1d']='25349' #brug af fysisk kraft eller anstrengelse rettet ..
key['vold1-2']='45387'#kontrol eller herredømme som en stærk person e... synset fra {magt_1}	det at have position og midler til at bestemme...	Property
key['vold1-1']='25330'
key['vold2-1']='37376'
key['vold2-1a']='66920'
#key['vold_2_1b']='32745'#overført banke, værn mod noget fra synset {værn_2}	fænomen el. forhold der fungerer som beskyttel...	UnboundedEvent+Phenomenal
#key['vold_F_give sig nogen/noget i vold']='69808'						
key['vold-F-gøre/øve-vold-mod/på']='25330'					
#key['vold_F_med Djævelens vold og magt']='45387'					
key['vold-F-med-vold-og-magt']='45387'				
#key['vold_F_pokker i vold']='37376'    #taget fra bogstavelig vold (banke)
#key['vold_F_stump vold']='25330'						
#key['vold_F_tage med vold']='52594'#fra {voldtægtsforsøg_0}	(ingen definition)	Dynamic+Agentive



key['B-selskab-1']='38195'
key['B-selskab-1a']='63014'
key['B-selskab-1b']='38195'#lagt sammen med hovedbetydning
key['B-selskab-1c']='6298'
key['B-selskab-2']='5685'
key['B-selskab-2a']='5686'
key['B-selskab-4']='16930'
key['B-selskab-4a']='33535'
key['B-selskab-3']='1834'
key['B-selskab-5']='33534'
key['B-selskab-F-holde-med-selskab']='38195'#fra {selskab_1}	det at være el. foretage sig noget sammen med ..




key['B-kontakt-2']='68735'#fra nærhed 1. #det at to genstande, dele, flader el.lign. er i fysisk forbindelse eller berøring med hinanden
key['B-kontakt-1a']='38217'
key['B-kontakt-1d']='38217'
key['B-kontakt-3']='1880'
key['B-kontakt-3a']='48752'
key['B-kontakt-1']='38217'
key['B-kontakt-1b']='7397'
key['B-kontakt-2a']='47379'
key['B-kontakt-1c']='42622'#fra forbindelse 2. #hvis [arrangørerne] ikke selv vil kontakte en foredragsholder, så sørger vi for kontakten
#key['B-kontakt-andet']=''


#key['Kurs 1']='38242'
#key['Kurs_1a']='77746'
#key['Kurs_2']='12912'
#key['Kurs_F_i høj kurs']='12912'
#key['Kurs_F_ikke i kurs']='38242'
#key['Kurs_F_sætte kursen']='38242'
#key['Kurs_F_ud/ude af kurs']='38242'

#OK DÅRLIGT ORD AT LINKE

key['stand-1']='25631'#	bestemt tilstand eller forfatning som noget (e...	property+physical		phenomenon		bestemt tilstand eller forfatning som noget (e...
key['stand-2']='32170'#	en persons stilling i samfundet, beroende på e...	3rdorder+mental+socuial		cognition		en persons stilling i samfundet, beroende på e...
key['stand-3']='5703'#	gruppe af personer der har samme erhverv eller...	3 x human+object+group		person		gruppe af personer der har samme erhverv eller...
key['stand-4']='18463'#	særligt indrettet, afgrænset område hvorfra de...	place+Object		location		særligt indrettet, afgrænset område hvorfra de...
#key['Stand_5']='59128'#	blomsterstade	plant+object+part		plant		blomsterstade
#key['Stand_6']='45406'#	position (i højden), især det niveau en væskes...	property+location		location		position (i højden), især det niveau en væskes...
#key['Stand_7']='25631'#IKKE I SYNSETS!!!!!!!   DEFAULT= STAND_1#	det at en jagthund står stille foran trykkende...	unboundedEvent+Physical+Location		location		det at en jagthund står stille foran trykkende...
#key['stand_F_af stand(gl.)']='32170'#						
key['stand-F-få/bringe-i-stand']='25631'#						
#key['stand_F_gøre sig i stand']='25631'#						
key['stand-F-gøre-(sætte,-lave,-..)-i-stand']='25631'						
key['stand-F-holde-stand']='25631'						
key['stand-F-i-stand-til']='25631'					
key['stand-F-komme-i-stand']='25631'					
key['stand-F-se-sig-i-stand-til']='25631'					
key['stand-F-ude-af-stand-til']='25631'						
#key['stand_F_være godt i stand']='25631'

#key['Tang_1_1_1a']='955'
#key['Tang_2_1']='35800'
#key['Tang_2_2']='59474'
#key['Tang_F_gloende tænger']='35800'
#key['Tang_F_tage med tang']='35800'


key['plads-1']='7571'#	sammenhængende areal eller rumfang der er frit...	Place+Object	Plads: dårligt eksempel – skyldes at DDO's bet...	location	masser af plads, ikke plads til	sammenhængende areal eller rumfang der er frit...
key['plads-1a']='57014'#	tid, penge eller andre resurser der gør det mu...	Static		state	plads til at gøre noget, give lads til at rejse	tid, penge eller andre resurser der gør det mu...
key['plads-2']='5071'#	sted hvor nogen eller noget anbringes eller be...	Place+Object x 2		location	nogets rette plads, nogens plads i et teater, fly	sted hvor nogen eller noget anbringes eller be...
key['plads-2a']='5086'
key['plads-2b']='32141'#lagt sammen med plads-7: post, embede "tilhørsforhold for en person til en bestemt gruppe, opnået ved valg, udtagelse el.lign.
key['plads-2c']='5071'# plads i mit hjerte. lagt sammen med plads-2
key['plads-3']='7567'
key['plads-3a']='7568'#	åbent, ubebygget område, ofte med en bestemt f...	Place+Object x 2		location	udendørs plads, torv	åbent, ubebygget område, ofte med en bestemt f...
key['plads-4']='72643'#	placering i en rangorden, et hierarki eller en...	Relation+location + Relation		relation	plads nr. 3, hans plads i hierarkiet	placering i en rangorden, et hierarki eller en...
key['plads-4a']='55201'
#key['Plads_5']='72554'#	ansættelse i en lønnet, typisk underordnet sti...	static+relation		relation	plads i huset, ansættelse	ansættelse i en lønnet, typisk underordnet sti...
key['plads-6']='55251'#	en persons adgang til noget, fx uddannelse, pa...	3orderentity		abstract	plads på universitetet, ledige pladser	en persons adgang til noget, fx uddannelse, pa...
key['plads-7']='32141'#	post; embede	static+relation		relation	en plads som vicepræsident	post; embede
key['plads-F-banke/sætte-på-plads']='5071'#						
key['plads-F-brikkerne-falder-på-plads']='5071'#						
key['plads-F-en-plads-i-solen']='7571'#						
#key['Plads_F_ikke meget (tid, plads, ..) at give (v...']='57014'#						
#key['Plads_F_løbe/rende af pladsen']='7571'						
#key['Plads_F_(på) plads']='5071'						
key['plads-F-på-plads']='5071'						
key['plads-F-på-pladserne']='5071'						
key['plads-F-sætte-tingene-på-plads']='5071'						
key['plads-F-tage-plads']='7571'						
key['plads-F-vige-pladsen']='7571'						
key['plads-F-være-på-sin-plads']='5071'

#key['Skud_1']='39818'
#key['Skud_10']='45304'# Fra islæt synonym
#key['Skud_1a']='49081'#fra {optagelse_1}	overførsel af lyd el. synsindtryk til fx bånd ...	BoundedEvent+Agentive+Physical+Purpos
#key['Skud_2']='32391'
#key['Skud_3']='36319'
#key['Skud_4']='39816'
#key['Skud_5']='37407'
#key['Skud_6']='38685'#Fra gæt_1_!
#ey['Skud_7']='72328'
#key['Skud_8']='9348'
#key['Skud_9']='48788'#fra {udsyn_1}	mulighed for at kunne se uhindret ud over et o...	UnboundedEvent+Experience+Physical
#key['skud_5a']='37407'
#key['skud_F_ løst skud']='36320'
#ey['skud_F_sidste (seneste, nyeste, ..) skud på stammen']='37407'
#key['skud_F_skarpt skud']='36321'
#key['skud_F_skud for boven']='32391'
#key['skud_F_skud fra hoften']='69574'
#key['skud_F_skud i foden']='32391'
#key['skud_F_skud i tågen']='32391'
#key['skud_F_stå for skud']='32391'

# %%
#alleord={}
#alleord['blik']=['Blik_1_1','Blik_1_2','Blik_1_3','Blik_1_4','Blik_1_4a','Blik_2_1_1a','Blik_F_finde nåde for nogens blik','Blik_F_få blikket','Blik_F_indre blik']
#alleord['hul']=[ 'hul_1a','hul_2a','hul_2b','hul_2c','Hul_1_1b_1e','Hul_1c','Hul_1d','Hul_1f','Hul_2','Hul_3','Hul_4_4a','Hul_F_(skid) hul i(=pyt med det)','Hul_F_drikke som et hul i jorden','Hul_F_få hul på noget','Hul_F_gå hul','Hul_F_hul i hovedet','Hul_F_hul i jorden','Hul_F_hul igennem', 'Hul_F_hul på bylden','Hul_F_skide hul i','Hul_F_slå (prikke, ..) hul på','Hul_F_sort hul','Hul_F_tage hul på noget']
#alleord['kontakt']=['kontakt_1_1a', 'Kontakt_1b','Kontakt_1c_1_d','Kontakt_2_2a','Kontakt_3_3a']
#alleord['kort']=[ 'Kort_1_1a_1b_1c_1d','Kort_2_2a','Kort_3','Kort_4','Kort_F_blande kortene','Kort_F_gult kort','Kort_F_gult kort_overført','Kort_F_have gode kort på hånden','Kort_F_holde kortene tæt ind til kroppen','Kort_F_kigge nogen i kortene','Kort_F_ligge i kortene','Kort_F_lægge kortene på bordet','Kort_F_røde kort','Kort_F_røde kort overført','Kort_F_spille med skjulte/fordækte kort','Kort_F_spille med åbne kort','Kort_F_spille sine kort godt/dårligt','Kort_F_sætte alt på et kort']
#alleord['kurs']=[ 'Kurs 1','Kurs_1a','Kurs_2','Kurs_F_i høj kurs','Kurs_F_ikke i kurs','Kurs_F_sætte kursen','Kurs_F_ud/ude af kurs']
#alleord['plade']=[ 'plade_F_sætte en anden/ny plade på grammofonen','Plade_1_1a','Plade_1b','Plade_1c','Plade_2','Plade_2a','Plade_3','Plade_4','Plade_5','Plade_6','Plade_7','Plade_F_barn på gule plader','Plade_F_fotografisk plade','Plade_F_gule plader','Plade_F_hvide plader','Plade_F_klippe pladerne','Plade_F_sorte plader','Plade_F_stikke en plade']
#alleord['plads']=[ 'Plads_1','Plads_1a','Plads_2_2a','Plads_2b_2c','Plads_3_3a','Plads_4_4a','Plads_5','Plads_6','Plads_7','Plads_F_(på) plads','Plads_F_banke/sætte på plads','Plads_F_brikkerne falder på plads','Plads_F_en plads i solen','Plads_F_ikke meget (tid, plads, ..) at give (væk) af)','Plads_F_løbe/rende af pladsen','Plads_F_på plads','Plads_F_på pladserne','Plads_F_sætte tingene på plads','Plads_F_tage plads','Plads_F_vige pladsen','Plads_F_være på sin plads']
#alleord['selskab']=[ 'Selskab_2_2a','Selskab_3','Selskab_4_4a','Selskab_5','Selskab_F_holde med selskab']
#alleord['skade']=[ 'Skade1_1','Skade2_1','Skade2_2','skade1_1a','skade1_1b_1c','skade_F_(det er/var) skade','skade_F_af skade bliver man klog','skade_F_det er ingen skade til','skade_F_føje spot til skade','skade_F_ikke komme nogen til skade','skade_F_komme for skade','skade_F_komme til skade','skade_F_slå halv skade','skade_F_tage skade for hjemgæld','skade_F_tage/lide skade']
#alleord['skud']=['Skud_1','Skud_10','Skud_1a','Skud_2','Skud_3','Skud_4','Skud_5','Skud_6','Skud_7','Skud_8','Skud_9','skud_5a','skud_F_ løst skud','skud_F_sidste (seneste, nyeste, ..) skud på stammen','skud_F_skarpt skud','skud_F_skud for boven','skud_F_skud fra hoften','skud_F_skud i foden','skud_F_skud i tågen','skud_F_stå for skud']
#alleord['slag']=[ 'slag_2a','Slag_1_1c','Slag_1a','Slag_1b','Slag_2_2b_2c','Slag_3_3a','Slag_4_4a', 'Slag_5','Slag_6_6b','Slag_7','Slag_8','Slag_F_frit slag','Slag_F_hjerte_springer_slag_over','Slag_F_klokken falder i slag','Slag_F_med ét slag','Slag_F_på slaget','Slag_F_slag i ansigtet','Slag_F_slag i bolledejen','Slag_F_slag i luften','Slag_F_slag i slag','Slag_F_slag på tasken','Slag_F_slag/stød under bæltestedet','Slag_F_slå et slag','Slag_F_små slag)','Slag_F_springe et (par) slag over','Slag_F_stor i slaget']
#alleord['stand']=[ 'stand_1','stand_F_af stand(gl.)','stand_F_få/bringe i stand', 'stand_F_gøre (sætte, lave, ..) i stand','stand_F_gøre sig i stand','stand_F_holde stand','stand_F_i stand til','stand_F_komme i stand','stand_F_se sig i stand til','stand_F_ude af stand til','stand_F_være godt i stand','Stand_2','Stand_3_3a_3b','Stand_4','Stand_5','Stand_6','Stand_7']
#alleord['stykke']=[ 'stykke_1','stykke_F_blæse noget/nogen et stykke','stykke_F_det var/er et stift stykke','stykke_F_en 4-5 (25, tusind, ..) stykker','stykke_F_et langt stykke (af vejen)/et langt stykke hen ad vejen','stykke_F_et stort stykke af(=et typisk eksempel på)','stykke_F_i det stykke(sj.)','stykke_F_i stumper og stykker','stykke_F_i stykker','stykke_F_når det kommer til stykket','stykke_F_pille fra hinanden (i, stykker, ..)','stykke_F_skide nogen/noget et stykke','stykke_F_slå i stykker','stykke_F_stykke mad(=smørrebrød)','stykke_F_være to alen (ud) af ét stykke','Stykke_1a','Stykke_2','Stykke_2a','Stykke_3','Stykke_3a','Stykke_4','Stykke_4a','Stykke_4b','Stykke_4c','Stykke_4d','Stykke_5','Stykke_5a_5b','Stykke_5c_5d','Stykke_6','Stykke_7']
#alleord['tang']=[ 'Tang_1_1_1a','Tang_2_1','Tang_2_2','Tang_F_gloende tænger','Tang_F_tage med tang']
#alleord['top']=['Top_1','Top_1a_1b','Top_2','Top_2a_2b','Top_3','Top_4','Top_F_der er koldt på toppen','Top_F_fra top til tå','Top_F_på toppen af','Top_F_til tops','Top_F_toppen af isbjerget','Top_F_toppen af/på kransekagen','Top_F_tånd/grå i toppen']
#alleord['ansigt']=['Ansigt_1','Ansigt_2','Ansigt_3_3a','ansigt_1a','ansigt_2a','ansigt_F_blive lang i ansigtet','ansigt_F_en våd klud i ansigtet','ansigt_F_i sit ansigts sved','ansigt_F_lige op i ansigtet/lige op i éns åbne ansigt','ansigt_F_lægge ansigtet i de rette folder','ansigt_F_med et menneskeligt ansigt','ansigt_F_på éns glatte/ærlige ansigt','ansigt_F_redde ansigt','ansigt_F_skære ansigt/ansigter/lave ansigt/ansigter','ansigt_F_slag i ansigtet','ansigt_F_slynge nogen noget i hovedet (ansigtet, ..)/slynge noget i hovedet (ansigtet, ..) på nogen','ansigt_F_stå ansigt til ansigt','ansigt_F_stå malet i ansigtet på nogen','ansigt_F_sætte ansigt på','ansigt_F_tabe/miste ansigt','ansigt_b']
#alleord['hold']=[ 'hold_1_1a_1b''hold_2','hold_3','hold_4','hold_5','hold_5a','hold_6','hold_6a','hold_7','hold_8','hold_F_på hold','hold_F_være/spille med på holdet']
#alleord['lys']=['Lys_2','lys_1_1a_1b_1c_1f''lys_1d','lys_1e','lys_1f','lys_1g','lys_3','lys_4','lys_5','lys_F_bengalsk lys','lys_F_brænde sit lys i begge ender','lys_F_der går et lys op for nogen','lys_F_føre nogen bag lyset','lys_F_grønt lys(for noget)','lys_F_grønt/gult/rødt lys','lys_F_gå ud som et lys','lys_F_i et nyt (andet, ..) lys','lys_F_i lyset af','lys_F_kaste lys over','lys_F_komme for dagens lys','lys_F_lede/søge med lys og lygte','lys_F_levende lys','lys_F_lys i mørket','lys_F_rank som et lys','lys_F_se dagens lys','lys_F_se lyset','lys_F_stille/sætte i et dårligt lys','lys_F_sætte sit lys under en skæppe','lys_F_tåle dagens lys']
#alleord['model']=[ 'model_1','model_1a','model_2','model_3','model_4','model_5','model_6_6a','model_F_stå model til']
#alleord['vold']=[ 'vold_1_1a','vold_1_1b','vold_1_1c','vold_1_1d','vold_1_2','vold_2_1_1a','vold_2_1b','vold_F_give sig nogen/noget i vold','vold_F_gøre/øve vold mod/på','vold_F_med Djævelens vold og magt','vold_F_med vold og magt','vold_F_pokker i vold','vold_F_stump vold','vold_F_tage med vold']

# %%
alleord={}
#alleord['kurs']=[] ikke i evalueringsdata
#alleord['skud']=[] ikke i evalueringsdata
#alleord['tang']=[] ikke i evalueringsdata

#16
alleord['ansigt']=['ansigt-1', 'ansigt-F-slag-i-ansigtet', 'ansigt-F-lige-op-i-ansigtet/lige-op-i-éns-åbne-ansigt', 'ansigt-F-stå-malet-i-ansigtet-på-nogen', 'ansigt-F-skære-ansigt/ansigter/lave-ansigt/ansigter', 'ansigt-F-en-våd-klud-i-ansigtet', 'ansigt-F-stå-ansigt-til-ansigt', 'ansigt-2', 'ansigt-F-tabe/miste-ansigt', 'ansigt-1b', 'ansigt-2a', 'ansigt-3', 'ansigt-F-sætte-ansigt-på', 'ansigt-1a', 'ansigt-3a', 'ansigt-F-med-et-menneskeligt-ansigt']
#8
alleord['blik']=['blik-F-indre-blik', 'blik-1-4a', 'blik-2-1', 'blik-1-2', 'blik-1-4', 'blik-1-1', 'blik-F-få-blikket', 'blik-1-3']
#10
alleord['hold']=['hold-8', 'hold-3', 'hold-6a', 'hold-5a', 'hold-1a', 'hold-1b', 'hold-F-på-hold', 'hold-1', 'hold-4', 'hold-2']
#22
alleord['hul']=['hul-4', 'hul-2c', 'hul-F-skide-hul-i', 'hul-F-sort-hul', 'hul-2a', 'hul-3', 'hul-1c', 'hul-1d', 'hul-1f', 'hul-1', 'hul-F-hul-i-jorden', 'hul-1-1b-1e', 'hul-2', 'hul-F-tage-hul-på-noget', 'hul-F-hul-igennem', 'hul-F-få-hul-på-noget', 'hul-F-gå-hul', 'hul-1a', 'hul-2b', 'hul-1b', 'hul-F-hul-på-bylden', 'hul-F-hul-i-hovedet']
#21
alleord['kort']=['kort-F-røde-kort-overført', 'kort-F-have-gode-kort-på-hånden', 'kort-F-røde-kort', 'kort-1a', 'kort-F-blande-kortene', 'kort-4', 'kort-F-gult-kort-overført', 'kort-F-spille-sine-kort-godt/dårligt', 'kort-F-kigge-nogen-i-kortene', 'kort-1c', 'kort-1', 'kort-F-ligge-i-kortene', 'kort-2a', 'kort-2', 'kort-F-holde-kortene-tæt-ind-til-kroppen', 'kort-F-gult-kort', 'kort-1b', 'kort-1e', 'kort-F-spille-med-åbne-kort', 'kort-3', 'kort-F-lægge-kortene-på-bordet']
#30
alleord['lys']=['lys-1f', 'lys-F-føre-nogen-bag-lyset', 'lys-F-kaste-lys-over', 'lys-F-grønt-lys(for-noget)', 'lys-F-tåle-dagens-lys', 'lys-F-lede/søge-med-lys-og-lygte', 'lys-F-lys-i-mørket', 'lys-4', 'lys-1c', 'lys-F-der-går-et-lys-op-for-nogen', 'lys-F-i-lyset-af', 'lys-5', 'lys-2', 'lys-1e', 'lys-1g', 'lys-1h', 'lys-1b', 'lys-F-grønt/gult/rødt-lys', 'lys-F-komme-for-dagens-lys', 'lys-F-se-dagens-lys', 'lys-F-se-lyset', 'lys-F-komme/bringe-frem-i-lyset', 'lys-1a', 'lys-F-sætte-sit-lys-under-en-skæppe', 'lys-F-i-et-nyt-(andet,-..)-lys', 'lys-F-stille/sætte-i-et-dårligt-lys', 'lys-1', 'lys-F-gå-ud-som-et-lys', 'lys-3', 'lys-1d']
#9
alleord['model']=['model-3', 'model-F-stå-model-til', 'model-6', 'model-1', 'model-6a', 'model-5', 'model-4', 'model-2', 'model-1a']
#13
alleord['plade']=['plade-5', 'plade-1a', 'plade-F-gule-plader', 'plade-F-panser-og-plade', 'plade-1b', 'plade-F-stikke-en-plade', 'plade-F-hvide-plader', 'plade-6', 'plade-1', 'plade-4', 'plade-2', 'plade-2a', 'plade-1c']
#21
alleord['plads']=['plads-2c', 'plads-F-banke/sætte-på-plads', 'plads-4', 'plads-F-en-plads-i-solen', 'plads-2b', 'plads-3a', 'plads-3', 'plads-4a', 'plads-F-på-pladserne', 'plads-2a', 'plads-2', 'plads-F-tage-plads', 'plads-6', 'plads-F-være-på-sin-plads', 'plads-1a', 'plads-1', 'plads-F-brikkerne-falder-på-plads', 'plads-F-sætte-tingene-på-plads', 'plads-F-på-plads', 'plads-F-vige-pladsen', 'plads-7']
#12
alleord['skade']=['skade-1-1', 'skade-F-(det-er/var)-skade', 'skade-1-1c', 'skade-F-komme-til-skade', 'skade-F-komme-for-skade', 'skade-1-1b', 'skade-2-1', 'skade-1-1a', 'skade-F-det-er-ingen-skade-til', 'skade-F-tage/lide-skade', 'skade-F-slå-halv-skade', 'skade-F-føje-spot-til-skade']
#28
alleord['slag']=['slag-F-slag-i-slag', 'slag-4a', 'slag-4', 'slag-F-klokken-falder-i-slag', 'slag-6b', 'slag-1', 'slag-7', 'slag-2b', 'slag-F-på-slaget', 'slag-F-hjerte-springer-slag-over', 'slag-1c', 'slag-3', 'slag-1b', 'slag-6', 'slag-1a', 'slag-F-stor-i-slaget', 'slag-3a', 'slag-F-slag-i-bolledejen', 'slag-F-slag-på-tasken', 'slag-F-slag-i-luften', 'slag-F-slag-i-ansigtet', 'slag-6a', 'slag-F-slå-et-slag', 'slag-2c', 'slag-2', 'slag-2a', 'slag-F-frit-slag', 'slag-F-med-ét-slag']
#11
alleord['stand']=['stand-F-få/bringe-i-stand', 'stand-F-holde-stand', 'stand-F-komme-i-stand', 'stand-F-gøre-(sætte,-lave,-..)-i-stand', 'stand-F-ude-af-stand-til', 'stand-4', 'stand-F-se-sig-i-stand-til', 'stand-1', 'stand-3', 'stand-2', 'stand-F-i-stand-til']
#22
alleord['stykke']=['stykke-3a', 'stykke-2', 'stykke-1', 'stykke-5', 'stykke-F-slå-i-stykker', 'stykke-1a', 'stykke-F-en-4-5-(25,-tusind,-..)-stykker', 'stykke-F-i-stumper-og-stykker', 'stykke-F-når-det-kommer-til-stykket', 'stykke-5d', 'stykke-3', 'stykke-F-et-langt-stykke-(af-vejen)/et-langt-stykke-hen-ad-vejen', 'stykke-4c', 'stykke-F-i-stykker', 'stykke-5a', 'stykke-5b', 'stykke-2a', 'stykke-4', 'stykke-5c', 'stykke-4b', 'stykke-4a', 'stykke-4d']
#12
alleord['top']=['top-1', 'top-2', 'top-F-toppen-af-isbjerget', 'top-2a', 'top-F-til-tops', 'top-2b', 'top-F-fra-top-til-tå', 'top-3', 'top-F-toppen-af/på-kransekagen', 'top-F-tånd/grå-i-toppen', 'top-F-på-toppen-af', 'top-1a']
#10
alleord['vold']=['vold-F-gøre/øve-vold-mod/på', 'vold1-1', 'vold2-1', 'vold2-1a', 'vold1-1b', 'vold1-1a', 'vold1-1d', 'vold-F-med-vold-og-magt', 'vold1-2', 'vold1-1c']
#10
alleord['kontakt']=['B-kontakt-2', 'B-kontakt-1a', 'B-kontakt-1d', 'B-kontakt-3', 'B-kontakt-3a', 'B-kontakt-1', 'B-kontakt-1b', 'B-kontakt-2a', 'B-kontakt-1c']#'B-kontakt-andet'
#11
alleord['selskab']=['B-selskab-1b', 'B-selskab-1c', 'B-selskab-3', 'B-selskab-4a', 'B-selskab-2', 'B-selskab-F-holde-med-selskab', 'B-selskab-4', 'B-selskab-5', 'B-selskab-2a', 'B-selskab-1', 'B-selskab-1a']

# %%
# In[3]: Some synsets did not have examples in the DanNet data (12). I found the missing parts from the danish dictionary website ordnet.dk
no_examples=['ansigt-1b', 'hul-4','kort-1','kort-1c','lys-1c','plade-6','slag-F-klokken-falder-i-slag','slag-F-med-ét-slag','slag-F-på-slaget','stykke-2a','stykke-5','top-2b']

#for k,m in key.items():
#    if len(find_example_content(m))==0:
#        print(k)

# #for x in no_examples:
#    print(key[x])       

#/Users/idarormannolsen/anaconda/lib/python3.6/re.py:212: FutureWarning: split() requires a non-empty pattern match.
#  return _compile(pattern, flags).split(string, maxsplit)
#ansigt-1b
#hul-4
#kort-1
#kort-1c
#lys-1c
#plade-6
#slag-F-klokken-falder-i-slag
#slag-F-med-ét-slag
#slag-F-på-slaget
#stykke-2a
#stykke-5
#top-2b
manually_found_examples={'15549':['månens' ,'ansigt'] ,'58363':['naturlig', 'åbning', 'i', 'et', 'menneskes', 'krop'] ,'20659':['pengeinstitutterne', 'der', 'afgør', 'hvornår', 'en', 'kunde' ,'skal', 'hæfte', 'for', 'en' ,'tyvs', 'misbrug', 'af', 'kort', 'og',' kode'] ,'58462':['jeg', 'har', 'slukket' ,'lyset', 'på', 'værelset', 'og', 'sidder' ,'og', 'skriver', 'i', 'stearinlysets', 'og', 'skærmens', 'forenede', 'skær'],'18526':['det','bliver','til','cirka','ti','kilowatt','det','svarer','sådan','nogenlunde','til','et','komfur','med','fire','plader','og','en','ovn','og','en','grill,','der','er','tændt','hele','tiden'],'67203':['ringenes', 'herre', 'ændrede', 'hendes', 'liv', 'med', 'ét', 'slag'],'67204':['jeg', 'ankom', 'til', 'hovedbanegården', 'på', 'slaget', '14'],'35533':['man','kan','operere','og','udskifte','et','stykke','af','en','blodåre'] ,'28274':['den','21','år','gamle','teaterforening','kan','godt','lide','traditionelle','stykker','med','sang'],'63072':['i','toppen','har','vi','ministeren','og','hans/hendes','stab','af','magtfulde','departementschefer','og','direktører,','kontorchefer','og','fuldmægtige']}
# From https://ordnet.dk/ddo/ordbog?query=targetword  Some of the examples are definitions. No examples found.

# %%
import pickle
pickle.dump(key, open("link_key.p", "wb"))
pickle.dump(alleord, open("alleord_med_tags.p", "wb"))
pickle.dump(manually_found_examples, open("manually_found_examples.p", "wb"))
#key = pickle.load(open("link_key.p", "rb"))
